# %%
#!pip install mpmath

# %%
import numpy as np
import mpmath as mp

# %%
#want = 0.346323362278580922064856552
want = 0.152673
#base = ['sqrt(2)','log(2)','e**(4/9)']

# %%
mp.identify(want)
# Out:
# '(2**(133/5)*7**(208/5))/(3**(247/5)*5**(146/5))'

# %%
for p in mp.identify(want, tol=1e-6, full=True):
    print(p)
# Out:
# ((-288+sqrt(107384))/260)
# 1/((288+sqrt(107384))/94)
# 1/sqrt(((35+sqrt(2581))/2))
# ((532-sqrt(155600))/352)**2
# log(((798+sqrt(2280))/726))
# sqrt(((-35+sqrt(2581))/678))
# 1/((532+sqrt(155600))/362)**2
# 1/log(((699+sqrt(489181))/2))
# log(1/((798-sqrt(2280))/874))
# exp(((-92-sqrt(591040))/458))
# (5*7**2)/(2**(5/3)*3**(17/3))
# 1/exp(((92+sqrt(591040))/458))
# exp(1/((92-sqrt(591040))/1272))

# %%
for p in mp.identify(want, base, tol=1e-10, full=True):
    print(p)
# Out:
# log(2)*log(((49/37) + (-215/111)*sqrt(2) + (218/111)*e**(4/9)))
# ((-10/27) + (-5/36)*sqrt(2) + (-1/4)*log(2) + (23/27)*e**(4/9))**2
# 1/((-19/135) + (20/27)*sqrt(2) + (11/27)*log(2) + (49/45)*e**(4/9))
# 1/((66/5) + (26/5)*sqrt(2) + (143/5)*log(2) + (-124/5)*e**(4/9))**2
# ((-19/716) + (5/358)*sqrt(2) + (367/716)*log(2) + (-1/716)*e**(4/9))
# log(((-97/80) + (13/16)*sqrt(2) + (-1/16)*log(2) + (39/40)*e**(4/9)))
# sqrt(2)/((73/9) + (58/9)*sqrt(2) + (49/6)*log(2) + (-217/18)*e**(4/9))
# sqrt(((-26/35) + (-59/70)*sqrt(2) + (-13/7)*log(2) + (15/7)*e**(4/9)))
# sqrt(((-85) + (-25/2)*sqrt(2) + 56*log(2) + 41*e**(4/9)))/sqrt(log(2))
# sqrt(2)*((-94/91) + 2*sqrt(2) + (-191/91)*log(2) + (9/91)*e**(4/9))**2
# e**(4/9)/log(((173/8) + (55/2)*sqrt(2) + (145/4)*log(2) + 3*e**(4/9)))
# e**(4/9)/((55/27) + (13/9)*sqrt(2) + (17/18)*log(2) + (-4/27)*e**(4/9))
# e**(4/9)/sqrt(((-112/3) + 63*sqrt(2) + (73/3)*log(2) + (-31)*e**(4/9)))
# ...
